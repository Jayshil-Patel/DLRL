# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Preprocess the data
x_train = x_train.reshape(x_train.shape[0], -1).astype('float32') / 255.0
x_test = x_test.reshape(x_test.shape[0], -1).astype('float32') / 255.0
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Softmax Regression model
def create_softmax_regression_model():
    model = Sequential([
        Dense(10, activation='softmax', input_shape=(784,))
    ])
    return model

# Softmax Regression model with Dropout
def create_softmax_regression_model_with_dropout():
    model = Sequential([
        Flatten(input_shape=(28, 28)),
        Dropout(0.2),
        Dense(10, activation='softmax')
    ])
    return model

# Softmax Regression model with BatchNormalization
def create_softmax_regression_model_with_batch_norm():
    model = Sequential([
        Flatten(input_shape=(28, 28)),
        BatchNormalization(),
        Dense(10, activation='softmax')
    ])
    return model

# Train and evaluate models
def train_and_evaluate(model, x_train, y_train, x_test, y_test):
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = model.fit(x_train, y_train, epochs=50, batch_size=32, validation_data=(x_test, y_test), verbose=1)
    return history.history['accuracy'], history.history['val_accuracy']

# Plot accuracy graph
def plot_accuracy_graph(accuracy, val_accuracy, title):
    plt.plot(accuracy, label='Training Accuracy')
    plt.plot(val_accuracy, label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title(title)
    plt.legend()
    plt.show()

# Plot accuracy graph
def plot_accuracy_graph_together(accuracy, val_accuracy, title, ax, lab):
    ax.plot(accuracy, label=lab)
    # ax.plot(val_accuracy, label='Validation Accuracy')
    ax.set_xlabel('Epochs')
    ax.set_ylabel('Accuracy')
    # ax.set_title(title)
    ax.legend()

# Create and train Softmax Regression model
softmax_model = create_softmax_regression_model()
softmax_accuracy, softmax_val_accuracy = train_and_evaluate(softmax_model, x_train, y_train, x_test, y_test)
plot_accuracy_graph(softmax_accuracy, softmax_val_accuracy, 'Softmax Regression Model')

# Create and train Softmax Regression model with Dropout
softmax_dropout_model = create_softmax_regression_model_with_dropout()
softmax_dropout_accuracy, softmax_dropout_val_accuracy = train_and_evaluate(softmax_dropout_model, x_train, y_train, x_test, y_test)
plot_accuracy_graph(softmax_dropout_accuracy, softmax_dropout_val_accuracy, 'Softmax Regression Model with Dropout')

# Create and train Softmax Regression model with BatchNormalization
softmax_batch_norm_model = create_softmax_regression_model_with_batch_norm()
softmax_batch_norm_accuracy, softmax_batch_norm_val_accuracy = train_and_evaluate(softmax_batch_norm_model, x_train, y_train, x_test, y_test)
plot_accuracy_graph(softmax_batch_norm_accuracy, softmax_batch_norm_val_accuracy, 'Softmax Regression Model with BatchNormalization')

#plotting for all together
plt.figure(figsize=(10, 6))
plot_accuracy_graph_together(softmax_accuracy, softmax_val_accuracy, 'Softmax Regression Model', plt.gca(),'Normal Softmax')
plot_accuracy_graph_together(softmax_dropout_accuracy, softmax_dropout_val_accuracy, 'Softmax Regression Model with Dropout', plt.gca(), 'With Dropout')
plot_accuracy_graph_together(softmax_batch_norm_accuracy, softmax_batch_norm_val_accuracy, 'Softmax Regression Model with BatchNormalization', plt.gca(), 'With batch Normalization')
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0
# 1875/1875 [==============================] - 2s 978us/step - loss: 0.2293 - accuracy: 0.9363 - val_loss: 0.2805 - val_accuracy: 0.9277
# Epoch 48/50
# 1875/1875 [==============================] - 2s 947us/step - loss: 0.2285 - accuracy: 0.9361 - val_loss: 0.2806 - val_accuracy: 0.9279
# Epoch 49/50
# 1875/1875 [==============================] - 2s 952us/step - loss: 0.2284 - accuracy: 0.9366 - val_loss: 0.2815 - val_accuracy: 0.9268
# Epoch 50/50
# 1875/1875 [==============================] - 2s 979us/step - loss: 0.2284 - accuracy: 0.9372 - val_loss: 0.2842 - val_accuracy: 0.9267
# Epoch 1/50
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name='flatten_9_input'), name='flatten_9_input', description="created by layer 'flatten_9_input'"), but it was called on an input with incompatible shape (32, 784).
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name='flatten_9_input'), name='flatten_9_input', description="created by layer 'flatten_9_input'"), but it was called on an input with incompatible shape (32, 784).
# 1854/1875 [============================>.] - ETA: 0s - loss: 0.5123 - accuracy: 0.8619WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name='flatten_9_input'), name='flatten_9_input', description="created by layer 'flatten_9_input'"), but it was called on an input with incompatible shape (None, 784).
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.5102 - accuracy: 0.8625 - val_loss: 0.3160 - val_accuracy: 0.9135
# Epoch 2/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3439 - accuracy: 0.9034 - val_loss: 0.2884 - val_accuracy: 0.9209
# Epoch 3/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3241 - accuracy: 0.9071 - val_loss: 0.2803 - val_accuracy: 0.9223
# Epoch 4/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3157 - accuracy: 0.9094 - val_loss: 0.2726 - val_accuracy: 0.9249
# Epoch 5/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3127 - accuracy: 0.9106 - val_loss: 0.2705 - val_accuracy: 0.9245
# Epoch 6/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3073 - accuracy: 0.9128 - val_loss: 0.2685 - val_accuracy: 0.9251
# Epoch 7/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3041 - accuracy: 0.9134 - val_loss: 0.2669 - val_accuracy: 0.9258
# Epoch 8/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3026 - accuracy: 0.9152 - val_loss: 0.2669 - val_accuracy: 0.9267
# Epoch 9/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3018 - accuracy: 0.9139 - val_loss: 0.2660 - val_accuracy: 0.9262
# Epoch 10/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2986 - accuracy: 0.9146 - val_loss: 0.2656 - val_accuracy: 0.9268
# Epoch 11/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2971 - accuracy: 0.9154 - val_loss: 0.2642 - val_accuracy: 0.9261
# Epoch 12/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2999 - accuracy: 0.9143 - val_loss: 0.2716 - val_accuracy: 0.9235
# Epoch 13/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3011 - accuracy: 0.9155 - val_loss: 0.2682 - val_accuracy: 0.9262
# Epoch 14/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2975 - accuracy: 0.9150 - val_loss: 0.2649 - val_accuracy: 0.9267
# Epoch 15/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2984 - accuracy: 0.9144 - val_loss: 0.2688 - val_accuracy: 0.9258
# Epoch 16/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2983 - accuracy: 0.9146 - val_loss: 0.2658 - val_accuracy: 0.9278
# Epoch 17/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2972 - accuracy: 0.9154 - val_loss: 0.2659 - val_accuracy: 0.9261
# Epoch 18/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2962 - accuracy: 0.9144 - val_loss: 0.2661 - val_accuracy: 0.9266
# Epoch 19/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2942 - accuracy: 0.9151 - val_loss: 0.2679 - val_accuracy: 0.9269
# Epoch 20/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2945 - accuracy: 0.9155 - val_loss: 0.2695 - val_accuracy: 0.9274
# Epoch 21/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2961 - accuracy: 0.9151 - val_loss: 0.2688 - val_accuracy: 0.9275
# Epoch 22/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2972 - accuracy: 0.9147 - val_loss: 0.2673 - val_accuracy: 0.9279
# Epoch 23/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2942 - accuracy: 0.9158 - val_loss: 0.2727 - val_accuracy: 0.9257
# Epoch 24/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2962 - accuracy: 0.9154 - val_loss: 0.2724 - val_accuracy: 0.9241
# Epoch 25/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2932 - accuracy: 0.9145 - val_loss: 0.2672 - val_accuracy: 0.9257
# Epoch 26/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2944 - accuracy: 0.9165 - val_loss: 0.2729 - val_accuracy: 0.9258
# Epoch 27/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2954 - accuracy: 0.9154 - val_loss: 0.2739 - val_accuracy: 0.9242
# Epoch 28/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2936 - accuracy: 0.9162 - val_loss: 0.2729 - val_accuracy: 0.9270
# Epoch 29/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2915 - accuracy: 0.9163 - val_loss: 0.2687 - val_accuracy: 0.9272
# Epoch 30/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2951 - accuracy: 0.9160 - val_loss: 0.2684 - val_accuracy: 0.9274
# Epoch 31/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2924 - accuracy: 0.9163 - val_loss: 0.2687 - val_accuracy: 0.9295
# Epoch 32/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2951 - accuracy: 0.9147 - val_loss: 0.2685 - val_accuracy: 0.9271
# Epoch 33/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2901 - accuracy: 0.9165 - val_loss: 0.2698 - val_accuracy: 0.9272
# Epoch 34/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2949 - accuracy: 0.9155 - val_loss: 0.2727 - val_accuracy: 0.9272
# Epoch 35/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2927 - accuracy: 0.9159 - val_loss: 0.2683 - val_accuracy: 0.9256
# Epoch 36/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2923 - accuracy: 0.9158 - val_loss: 0.2712 - val_accuracy: 0.9262
# Epoch 37/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2928 - accuracy: 0.9164 - val_loss: 0.2740 - val_accuracy: 0.9263
# Epoch 38/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2916 - accuracy: 0.9169 - val_loss: 0.2716 - val_accuracy: 0.9273
# Epoch 39/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2907 - accuracy: 0.9165 - val_loss: 0.2686 - val_accuracy: 0.9272
# Epoch 40/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2948 - accuracy: 0.9152 - val_loss: 0.2739 - val_accuracy: 0.9261
# Epoch 41/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2931 - accuracy: 0.9169 - val_loss: 0.2810 - val_accuracy: 0.9247
# Epoch 42/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2923 - accuracy: 0.9156 - val_loss: 0.2695 - val_accuracy: 0.9273
# Epoch 43/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2943 - accuracy: 0.9147 - val_loss: 0.2710 - val_accuracy: 0.9283
# Epoch 44/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2906 - accuracy: 0.9171 - val_loss: 0.2741 - val_accuracy: 0.9273
# Epoch 45/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2943 - accuracy: 0.9153 - val_loss: 0.2727 - val_accuracy: 0.9275
# Epoch 46/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2935 - accuracy: 0.9168 - val_loss: 0.2749 - val_accuracy: 0.9270
# Epoch 47/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2900 - accuracy: 0.9174 - val_loss: 0.2723 - val_accuracy: 0.9268
# Epoch 48/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2917 - accuracy: 0.9169 - val_loss: 0.2731 - val_accuracy: 0.9290
# Epoch 49/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2912 - accuracy: 0.9158 - val_loss: 0.2765 - val_accuracy: 0.9262
# Epoch 50/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2927 - accuracy: 0.9166 - val_loss: 0.2721 - val_accuracy: 0.9279
# Epoch 1/50
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name='flatten_10_input'), name='flatten_10_input', description="created by layer 'flatten_10_input'"), but it was called on an input with incompatible shape (32, 784).
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name='flatten_10_input'), name='flatten_10_input', description="created by layer 'flatten_10_input'"), but it was called on an input with incompatible shape (32, 784).
# 1867/1875 [============================>.] - ETA: 0s - loss: 0.4098 - accuracy: 0.8803WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name='flatten_10_input'), name='flatten_10_input', description="created by layer 'flatten_10_input'"), but it was called on an input with incompatible shape (None, 784).
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4098 - accuracy: 0.8803 - val_loss: 0.3022 - val_accuracy: 0.9178
# Epoch 2/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3233 - accuracy: 0.9062 - val_loss: 0.3108 - val_accuracy: 0.9163
# Epoch 3/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3120 - accuracy: 0.9092 - val_loss: 0.3096 - val_accuracy: 0.9194
# Epoch 4/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3105 - accuracy: 0.9105 - val_loss: 0.3156 - val_accuracy: 0.9179
# Epoch 5/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3054 - accuracy: 0.9131 - val_loss: 0.3208 - val_accuracy: 0.9180
# Epoch 6/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3031 - accuracy: 0.9140 - val_loss: 0.3231 - val_accuracy: 0.9168
# Epoch 7/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3046 - accuracy: 0.9132 - val_loss: 0.3263 - val_accuracy: 0.9186
# Epoch 8/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2984 - accuracy: 0.9151 - val_loss: 0.3218 - val_accuracy: 0.9178
# Epoch 9/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2958 - accuracy: 0.9161 - val_loss: 0.3257 - val_accuracy: 0.9173
# Epoch 10/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2962 - accuracy: 0.9158 - val_loss: 0.3330 - val_accuracy: 0.9159
# Epoch 11/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2951 - accuracy: 0.9155 - val_loss: 0.3304 - val_accuracy: 0.9155
# Epoch 12/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2937 - accuracy: 0.9168 - val_loss: 0.3305 - val_accuracy: 0.9180
# Epoch 13/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2953 - accuracy: 0.9151 - val_loss: 0.3332 - val_accuracy: 0.9187
# Epoch 14/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2929 - accuracy: 0.9167 - val_loss: 0.3316 - val_accuracy: 0.9171
# Epoch 15/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2938 - accuracy: 0.9169 - val_loss: 0.3378 - val_accuracy: 0.9182
# Epoch 16/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2929 - accuracy: 0.9158 - val_loss: 0.3399 - val_accuracy: 0.9165
# Epoch 17/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2897 - accuracy: 0.9165 - val_loss: 0.3427 - val_accuracy: 0.9148
# Epoch 18/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2920 - accuracy: 0.9162 - val_loss: 0.3393 - val_accuracy: 0.9195
# Epoch 19/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2902 - accuracy: 0.9165 - val_loss: 0.3393 - val_accuracy: 0.9162
# Epoch 20/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.
50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2848 - accuracy: 0.9176 - val_loss: 0.3470 - val_accuracy: 0.9169

# %% [markdown]
# ### Observations and Analysis:
#
# 1. **Softmax Regression Model (Normal):**
#    - The accuracy starts at approximately 87.98% and steadily increases over the epochs, reaching around 93.52% by the 30th epoch.
#    - The accuracy continues to increase but at a slower rate, indicating that the model is learning and refining its predictions as more epochs progress.
#    - The trend shows a consistent improvement in accuracy, suggesting that the model is effectively learning the features and patterns in the data.
#
# 2. **Softmax Regression Model with Dropout:**
#    - The accuracy starts at approximately 86.20% and shows a similar increasing trend but with more fluctuations compared to the normal softmax model.
#    - Dropout helps reduce overfitting, and despite fluctuations, the accuracy steadily improves, reaching around 91.69% by the 30th epoch.
#    - The fluctuations may be due to dropout's stochastic nature, where different sets of neurons are dropped during each training batch, affecting the training process.
#
# 3. **Softmax Regression Model with BatchNormalization:**
#    - The accuracy starts at approximately 88.06% and exhibits a smooth and steady increase throughout the epochs, reaching around 91.83% by the 30th epoch.
#    - Batch normalization helps in stabilizing and accelerating the learning process, leading to a more consistent and faster convergence compared to the normal softmax model.
#    - The trend suggests that batch normalization allows the model to learn more efficiently and achieve a higher accuracy within the same number of epochs.
#
# ### Summary:
# - The normal softmax regression model shows a consistent and steady increase in accuracy over the epochs.
# - The softmax regression model with dropout exhibits slightly more fluctuations but still demonstrates an overall increasing trend in accuracy.
# - The softmax regression model with batch normalization demonstrates a smooth and steady increase in accuracy, showcasing the benefits of batch normalization in stabilizing and accelerating the learning process.
#
# These observations indicate that techniques like dropout and batch normalization can aid in improving model performance and stability during training.

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Preprocess the data
x_train = x_train.reshape(x_train.shape[0], -1).astype('float32') / 255.0
x_test = x_test.reshape(x_test.shape[0], -1).astype('float32') / 255.0
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# MLP model
def create_mlp_model():
    model = Sequential([
        Dense(128, activation='relu', input_shape=(784,)),
        Dense(64, activation='relu'),
        Dense(10, activation='softmax')
    ])
    return model

# MLP model with Dropout
def create_mlp_model_with_dropout():
    model = Sequential([
        Flatten(input_shape=(28, 28)),
        Dropout(0.2),
        Dense(128, activation='relu'),
        Dropout(0.2),
        Dense(64, activation='relu'),
        Dense(10, activation='softmax')
    ])
    return model

# MLP model with BatchNormalization
def create_mlp_model_with_batch_norm():
    model = Sequential([
        Flatten(input_shape=(28, 28)),
        BatchNormalization(),
        Dense(128, activation='relu'),
        Dense(64, activation='relu'),
        Dense(10, activation='softmax')
    ])
    return model

# Create and train MLP model
mlp_model = create_mlp_model()
mlp_accuracy, mlp_val_accuracy = train_and_evaluate(mlp_model, x_train, y_train, x_test, y_test)
plot_accuracy_graph(mlp_accuracy, mlp_val_accuracy, 'MLP Model')

# Create and train MLP model with Dropout
mlp_dropout_model = create_mlp_model_with_dropout()
mlp_dropout_accuracy, mlp_dropout_val_accuracy = train_and_evaluate(mlp_dropout_model, x_train, y_train, x_test, y_test)
plot_accuracy_graph(mlp_dropout_accuracy, mlp_dropout_val_accuracy, 'MLP Model with Dropout')

# Create and train MLP model with BatchNormalization
mlp_batch_norm_model = create_mlp_model_with_batch_norm()
mlp_batch_norm_accuracy, mlp_batch_norm_val_accuracy = train_and_evaluate(mlp_batch_norm_model, x_train, y_train, x_test, y_test)
plot_accuracy_graph(mlp_batch_norm_accuracy, mlp_batch_norm_val_accuracy, 'MLP Model with BatchNormalization')

#plotting for all together
plt.figure(figsize=(10, 6))
plot_accuracy_graph_together(mlp_accuracy, mlp_val_accuracy, 'MLP Model', plt.gca(),'Normal MLP')
plot_accuracy_graph_together(mlp_dropout_accuracy, mlp_dropout_val_accuracy, 'MLP Model with Dropout', plt.gca(), 'With Dropout')
plot_accuracy_graph_together(mlp_batch_norm_accuracy, mlp_batch_norm_val_accuracy, 'MLP Model with BatchNormalization', plt.gca(), 'With batch Normalization')
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2439 - accuracy: 0.9288 - val_loss: 0.1128 - val_accuracy: 0.9665
# Epoch 2/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1048 - accuracy: 0.9683 - val_loss: 0.0944 - val_accuracy: 0.9701
# Epoch 3/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0733 - accuracy: 0.9770 - val_loss: 0.1078 - val_accuracy: 0.9648
# Epoch 4/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0555 - accuracy: 0.9823 - val_loss: 0.0817 - val_accuracy: 0.9751
# Epoch 5/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0438 - accuracy: 0.9849 - val_loss: 0.0956 - val_accuracy: 0.9718
# Epoch 6/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0364 - accuracy: 0.9883 - val_loss: 0.0898 - val_accuracy: 0.9760
# Epoch 7/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0298 - accuracy: 0.9898 - val_loss: 0.0852 - val_accuracy: 0.9760
# Epoch 8/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0255 - accuracy: 0.9918 - val_loss: 0.0967 - val_accuracy: 0.9770
# Epoch 9/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0224 - accuracy: 0.9927 - val_loss: 0.0791 - val_accuracy: 0.9779
# Epoch 10/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0181 - accuracy: 0.9940 - val_loss: 0.0914 - val_accuracy: 0.9769
# Epoch 11/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0178 - accuracy: 0.9942 - val_loss: 0.0976 - val_accuracy: 0.9791
# Epoch 12/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0154 - accuracy: 0.9948 - val_loss: 0.1093 - val_accuracy: 0.9774
# Epoch 13/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0151 - accuracy: 0.9949 - val_loss: 0.1056 - val_accuracy: 0.9789
# Epoch 14/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0127 - accuracy: 0.9958 - val_loss: 0.0926 - val_accuracy: 0.9800
# Epoch 15/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0144 - accuracy: 0.9951 - val_loss: 0.1082 - val_accuracy: 0.9766
# Epoch 16/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0126 - accuracy: 0.9959 - val_loss: 0.1168 - val_accuracy: 0.9787
# Epoch 17/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0086 - accuracy: 0.9971 - val_loss: 0.1105 - val_accuracy: 0.9795
# Epoch 18/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0121 - accuracy: 0.9960 - val_loss: 0.1117 - val_accuracy: 0.9772
# Epoch 19/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0113 - accuracy: 0.9966 - val_loss: 0.1144 - val_accuracy: 0.9797
# Epoch 20/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0106 - accuracy: 0.9964 - val_loss: 0.1173 - val_accuracy: 0.9784
# Epoch 21/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0100 - accuracy: 0.9968 - val_loss: 0.1449 - val_accuracy: 0.9779
# Epoch 22/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0074 - accuracy: 0.9974 - val_loss: 0.1733 - val_accuracy: 0.9731
# Epoch 23/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0092 - accuracy: 0.9969 - val_loss: 0.1308 - val_accuracy: 0.9778
# Epoch 24/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0090 - accuracy: 0.9971 - val_loss: 0.1434 - val_accuracy: 0.9763
# Epoch 25/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0082 - accuracy: 0.9975 - val_loss: 0.1102 - val_accuracy: 0.9798
# Epoch 26/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0092 - accuracy: 0.9973 - val_loss: 0.1139 - val_accuracy: 0.9797
# Epoch 27/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0060 - accuracy: 0.9980 - val_loss: 0.1360 - val_accuracy: 0.9782
# Epoch 28/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0099 - accuracy: 0.9972 - val_loss: 0.1410 - val_accuracy: 0.9806
# Epoch 29/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0072 - accuracy: 0.9979 - val_loss: 0.1574 - val_accuracy: 0.9783
# Epoch 30/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0081 - accuracy: 0.9976 - val_loss: 0.1495 - val_accuracy: 0.9785
# Epoch 31/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0071 - accuracy: 0.9980 - val_loss: 0.1346 - val_accuracy: 0.9796
# Epoch 32/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0089 - accuracy: 0.9975 - val_loss: 0.1395 - val_accuracy: 0.9801
# Epoch 33/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0071 - accuracy: 0.9980 - val_loss: 0.1660 - val_accuracy: 0.9783
# Epoch 34/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0074 - accuracy: 0.9977 - val_loss: 0.1592 - val_accuracy: 0.9785
# Epoch 35/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0082 - accuracy: 0.9975 - val_loss: 0.1519 - val_accuracy: 0.9793
# Epoch 36/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0059 - accuracy: 0.9982 - val_loss: 0.1647 - val_accuracy: 0.9776
# Epoch 37/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0070 - accuracy: 0.9979 - val_loss: 0.1616 - val_accuracy: 0.9800
# Epoch 38/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0058 - accuracy: 0.9982 - val_loss: 0.1590 - val_accuracy: 0.9786
# Epoch 39/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0066 - accuracy: 0.9981 - val_loss: 0.1614 - val_accuracy: 0.9780
# Epoch 40/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0057 - accuracy: 0.9982 - val_loss: 0.1930 - val_accuracy: 0.9734
# Epoch 41/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0066 - accuracy: 0.9982 - val_loss: 0.1806 - val_accuracy: 0.9792
# Epoch 42/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0071 - accuracy: 0.9981 - val_loss: 0.2015 - val_accuracy: 0.9765
# Epoch 43/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0056 - accuracy: 0.9984 - val_loss: 0.1913 - val_accuracy: 0.9761
# Epoch 44/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0071 - accuracy: 0.9978 - val_loss: 0.1805 - val_accuracy: 0.9783
# Epoch 45/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0052 - accuracy: 0.9985 - val_loss: 0.1831 - val_accuracy: 0.9792
# Epoch 46/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0074 - accuracy: 0.9981 - val_loss: 0.1941 - val_accuracy: 0.9783
# Epoch 47/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0063 - accuracy: 0.9984 - val_loss: 0.1627 - val_accuracy: 0.9823
# Epoch 48/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 0.1877 - val_accuracy: 0.9787
# Epoch 49/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0079 - accuracy: 0.9978 - val_loss: 0.1850 - val_accuracy: 0.9811
# Epoch 50/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0052 - accuracy: 0.9984 - val_loss: 0.1964 - val_accuracy: 0.9785
# Epoch 1/50
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name='flatten_11_input'), name='flatten_11_input', description="created by layer 'flatten_11_input'"), but it was called on an input with incompatible shape (32, 784).
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name='flatten_11_input'), name='flatten_11_input', description="created by layer 'flatten_11_input'"), but it was called on an input with incompatible shape (32, 784).
# 1855/1875 [============================>.] - ETA: 0s - loss: 0.3359 - accuracy: 0.8979WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name='flatten_11_input'), name='flatten_11_input', description="created by layer 'flatten_11_input'"), but it was called on an input with incompatible shape (None, 784).
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3346 - accuracy: 0.8983 - val_loss: 0.1351 - val_accuracy: 0.9601
# Epoch 2/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1693 - accuracy: 0.9473 - val_loss: 0.0972 - val_accuracy: 0.9708
# Epoch 3/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1379 - accuracy: 0.9564 - val_loss: 0.0848 - val_accuracy: 0.9745
# Epoch 4/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1203 - accuracy: 0.9620 - val_loss: 0.0824 - val_accuracy: 0.9746
# Epoch 5/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1111 - accuracy: 0.9656 - val_loss: 0.0720 - val_accuracy: 0.9783
# Epoch 6/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1002 - accuracy: 0.9681 - val_loss: 0.0691 - val_accuracy: 0.9777
# Epoch 7/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0939 - accuracy: 0.9704 - val_loss: 0.0711 - val_accuracy: 0.9763
# Epoch 8/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0886 - accuracy: 0.9714 - val_loss: 0.0654 - val_accuracy: 0.9820
# Epoch 9/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0829 - accuracy: 0.9730 - val_loss: 0.0706 - val_accuracy: 0.9787
# Epoch 10/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0811 - accuracy: 0.9741 - val_loss: 0.0704 - val_accuracy: 0.9787
# Epoch 11/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0762 - accuracy: 0.9754 - val_loss: 0.0619 - val_accuracy: 0.9815
# Epoch 12/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0744 - accuracy: 0.9749 - val_loss: 0.0694 - val_accuracy: 0.9803
# Epoch 13/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0717 - accuracy: 0.9763 - val_loss: 0.0633 - val_accuracy: 0.9805
# Epoch 14/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0698 - accuracy: 0.9770 - val_loss: 0.0654 - val_accuracy: 0.9795
# Epoch 15/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0709 - accuracy: 0.9766 - val_loss: 0.0671 - val_accuracy: 0.9804
# Epoch 16/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0665 - accuracy: 0.9786 - val_loss: 0.0659 - val_accuracy: 0.9808
# Epoch 17/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0654 - accuracy: 0.9781 - val_loss: 0.0614 - val_accuracy: 0.9823
# Epoch 18/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0652 - accuracy: 0.9787 - val_loss: 0.0631 - val_accuracy: 0.9818
# Epoch 19/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0607 - accuracy: 0.9798 - val_loss: 0.0654 - val_accuracy: 0.9789
# Epoch 20/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0608 - accuracy: 0.9801 - val_loss: 0.0607 - val_accuracy: 0.9827
# Epoch 21/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0605 - accuracy: 0.9803 - val_loss: 0.0638 - val_accuracy: 0.9821
# Epoch 22/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0594 - accuracy: 0.9811 - val_loss: 0.0624 - val_accuracy: 0.9834
# Epoch 23/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0604 - accuracy: 0.9803 - val_loss: 0.0656 - val_accuracy: 0.9816
# Epoch 24/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0569 - accuracy: 0.9805 - val_loss: 0.0623 - val_accuracy: 0.9814
# Epoch 25/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0577 - accuracy: 0.9805 - val_loss: 0.0658 - val_accuracy: 0.9800
# Epoch 26/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0553 - accuracy: 0.9818 - val_loss: 0.0683 - val_accuracy: 0.9810
# Epoch 27/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0573 - accuracy: 0.9818 - val_loss: 0.0671 - val_accuracy: 0.9814
# Epoch 28/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0542 - accuracy: 0.9819 - val_loss: 0.0738 - val_accuracy: 0.9810
# Epoch 29/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0562 - accuracy: 0.9814 - val_loss: 0.0651 - val_accuracy: 0.9812
# Epoch 30/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0530 - accuracy: 0.9824 - val_loss: 0.0737 - val_accuracy: 0.9807
# Epoch 31/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0535 - accuracy: 0.9823 - val_loss: 0.0709 - val_accuracy: 0.9802
# Epoch 32/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0530 - accuracy: 0.9829 - val_loss: 0.0673 - val_accuracy: 0.9814
# Epoch 33/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0529 - accuracy: 0.9830 - val_loss: 0.0678 - val_accuracy: 0.9825
# Epoch 34/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0510 - accuracy: 0.9832 - val_loss: 0.0734 - val_accuracy: 0.9812
# Epoch 35/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0508 - accuracy: 0.9833 - val_loss: 0.0690 - val_accuracy: 0.9813
# Epoch 36/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0490 - accuracy: 0.9834 - val_loss: 0.0681 - val_accuracy: 0.9832
# Epoch 37/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0509 - accuracy: 0.9833 - val_loss: 0.0667 - val_accuracy: 0.9819
# Epoch 38/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0483 - accuracy: 0.9844 - val_loss: 0.0702 - val_accuracy: 0.9830
# Epoch 39/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0507 - accuracy: 0.9832 - val_loss: 0.0675 - val_accuracy: 0.9836
# Epoch 40/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0489 - accuracy: 0.9833 - val_loss: 0.0643 - val_accuracy: 0.9833
# Epoch 41/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0512 - accuracy: 0.9833 - val_loss: 0.0701 - val_accuracy: 0.9818
# Epoch 42/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0470 - accuracy: 0.9847 - val_loss: 0.0655 - val_accuracy: 0.9828
# Epoch 43/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0488 - accuracy: 0.9840 - val_loss: 0.0650 - val_accuracy: 0.9827
# Epoch 44/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0475 - accuracy: 0.9844 - val_loss: 0.0642 - val_accuracy: 0.9837
# Epoch 45/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0475 - accuracy: 0.9847 - val_loss: 0.0615 - val_accuracy: 0.9833
# Epoch 46/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0450 - accuracy: 0.9853 - val_loss: 0.0673 - val_accuracy: 0.9835
# Epoch 47/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0468 - accuracy: 0.9843 - val_loss: 0.0657 - val_accuracy: 0.9834
# Epoch 48/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0449 - accuracy: 0.9852 - val_loss: 0.0711 - val_accuracy: 0.9828
# Epoch 49/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0471 - accuracy: 0.9847 - val_loss: 0.0660 - val_accuracy: 0.9831
# Epoch 50/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0436 - accuracy: 0.9850 - val_loss: 0.0613 - val_accuracy: 0.9824
# Epoch 1/50
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name='flatten_12_input'), name='flatten_12_input', description="created by layer 'flatten_12_input'"), but it was called on an input with incompatible shape (32, 784).
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name='flatten_12_input'), name='flatten_12_input', description="created by layer 'flatten_12_input'"), but it was called on an input with incompatible shape (32, 784).
# 1852/1875 [============================>.] - ETA: 0s - loss: 0.2238 - accuracy: 0.9317WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name='flatten_12_input'), name='flatten_12_input', description="created by layer 'flatten_12_input'"), but it was called on an input with incompatible shape (None, 784).
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.
50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0197 - accuracy: 0.9937 - val_loss: 0.1676 - val_accuracy: 0.9758
# Epoch 31/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0167 - accuracy: 0.9950 - val_loss: 0.1939 - val_accuracy: 0.9739
# Epoch 32/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0177 - accuracy: 0.9945 - val_loss: 0.2065 - val_accuracy: 0.9733
# Epoch 33/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0157 - accuracy: 0.9953 - val_loss: 0.1871 - val_accuracy: 0.9741
# Epoch 34/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0171 - accuracy: 0.9952 - val_loss: 0.1947 - val_accuracy: 0.9737
# Epoch 35/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0162 - accuracy: 0.9949 - val_loss: 0.1792 - val_accuracy: 0.9758
# Epoch 36/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0148 - accuracy: 0.9954 - val_loss: 0.1758 - val_accuracy: 0.9763
# Epoch 37/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0170 - accuracy: 0.9953 - val_loss: 0.2100 - val_accuracy: 0.9742
# Epoch 38/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0132 - accuracy: 0.9959 - val_loss: 0.2032 - val_accuracy: 0.9752
# Epoch 39/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0149 - accuracy: 0.9953 - val_loss: 0.2278 - val_accuracy: 0.9731
# Epoch 40/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0163 - accuracy: 0.9952 - val_loss: 0.1992 - val_accuracy: 0.9755
# Epoch 41/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0132 - accuracy: 0.9958 - val_loss: 0.2312 - val_accuracy: 0.9743
# Epoch 42/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0159 - accuracy: 0.9952 - val_loss: 0.2255 - val_accuracy: 0.9736
# Epoch 43/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0165 - accuracy: 0.9954 - val_loss: 0.2112 - val_accuracy: 0.9760
# Epoch 44/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0165 - accuracy: 0.9954 - val_loss: 0.2070 - val_accuracy: 0.9742
# Epoch 45/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0136 - accuracy: 0.9962 - val_loss: 0.2052 - val_accuracy: 0.9756
# Epoch 46/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0143 - accuracy: 0.9960 - val_loss: 0.2162 - val_accuracy: 0.9750
# Epoch 47/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0146 - accuracy: 0.9960 - val_loss: 0.2344 - val_accuracy: 0.9744
# Epoch 48/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0147 - accuracy: 0.9958 - val_loss: 0.2222 - val_accuracy: 0.9753
# Epoch 49/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0138 - accuracy: 0.9959 - val_loss: 0.2265 - val_accuracy: 0.9743
# Epoch 50/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0148 - accuracy: 0.9959 - val_loss: 0.2637 - val_accuracy: 0.9761

# %% [markdown]
# ### Observations and Analysis:
#
# 1. **MLP Model (Normal):**
#    - The accuracy starts at approximately 92.72% and demonstrates a rapid increase in accuracy within the initial epochs, reaching around 99.84% by the 30th epoch.
#    - The model quickly converges to a very high accuracy, suggesting that the architecture and learning process of an MLP model are effective for this dataset.
#    - The trend indicates that the model effectively learns the features and patterns in the data and achieves a high accuracy within a relatively small number of epochs.
#
# 2. **MLP Model with Dropout:**
#    - The accuracy starts at approximately 90.13% and exhibits a similar increasing trend to the normal MLP model, but with more fluctuations and a slightly slower rate of increase.
#    - Dropout helps reduce overfitting, leading to a more generalizable model. However, this can introduce fluctuations in the accuracy as the dropout layers randomly "turn off" neurons during training.
#    - The fluctuations in accuracy indicate the stochastic nature of dropout, affecting the model's performance during training.
#
# 3. **MLP Model with BatchNormalization:**
#    - The accuracy starts at approximately 93.02% and follows a smooth and steady increase, reaching around 99.48% by the 30th epoch.
#    - Batch normalization helps in stabilizing and accelerating the learning process, leading to a smoother accuracy curve and faster convergence compared to the normal MLP model.
#    - The trend suggests that batch normalization allows the model to learn more efficiently and achieve a high accuracy within the same number of epochs.
#
# ### Summary:
# - The normal MLP model demonstrates a rapid and consistent increase in accuracy, converging quickly to a very high accuracy.
# - The MLP model with dropout exhibits a similar increasing trend but with more fluctuations, highlighting the effect of dropout in reducing overfitting.
# - The MLP model with batch normalization showcases a smooth and steady increase in accuracy, demonstrating the benefits of batch normalization in stabilizing and accelerating the learning process.
#
# These observations provide insights into how techniques like dropout and batch normalization can influence the training dynamics and performance of MLP models.

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Preprocess the data
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1).astype('float32') / 255.0
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1).astype('float32') / 255.0
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# CNN model
def create_cnn_model():
    model = Sequential([
        Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(128, activation='relu'),
        Dense(10, activation='softmax')
    ])
    return model

# CNN model with Dropout
def create_cnn_model_with_dropout():
    model = Sequential([
        Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dropout(0.2),
        Dense(128, activation='relu'),
        Dense(10, activation='softmax')
    ])
    return model

# CNN model with BatchNormalization
def create_cnn_model_with_batch_norm():
    model = Sequential([
        Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
        MaxPooling2D((2, 2)),
        Flatten(),
        BatchNormalization(),
        Dense(128, activation='relu'),
        Dense(10, activation='softmax')
    ])
    return model

# Create and train CNN model
cnn_model = create_cnn_model()
cnn_accuracy, cnn_val_accuracy = train_and_evaluate(cnn_model, x_train, y_train, x_test, y_test)
plot_accuracy_graph(cnn_accuracy, cnn_val_accuracy, 'CNN Model')

# Create and train CNN model with Dropout
cnn_dropout_model = create_cnn_model_with_dropout()
cnn_dropout_accuracy, cnn_dropout_val_accuracy = train_and_evaluate(cnn_dropout_model, x_train, y_train, x_test, y_test)
plot_accuracy_graph(cnn_dropout_accuracy, cnn_dropout_val_accuracy, 'CNN Model with Dropout')

# Create and train CNN model with BatchNormalization
cnn_batch_norm_model = create_cnn_model_with_batch_norm()
cnn_batch_norm_accuracy, cnn_batch_norm_val_accuracy = train_and_evaluate(cnn_batch_norm_model, x_train, y_train, x_test, y_test)
plot_accuracy_graph(cnn_batch_norm_accuracy, cnn_batch_norm_val_accuracy, 'CNN Model with BatchNormalization')

#plotting for all together
plt.figure(figsize=(10, 6))
plot_accuracy_graph_together(cnn_accuracy, cnn_val_accuracy, 'CNN Model', plt.gca(),'Normal CNN')
plot_accuracy_graph_together(cnn_dropout_accuracy, cnn_dropout_val_accuracy, 'CNN Model with Dropout', plt.gca(), 'With Dropout')
plot_accuracy_graph_together(cnn_batch_norm_accuracy, cnn_batch_norm_val_accuracy, 'CNN Model with BatchNormalization', plt.gca(), 'With batch Normalization')
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 15s 7ms/step - loss: 0.1069 - accuracy: 0.9672 - val_loss: 0.0594 - val_accuracy: 0.9809
# Epoch 2/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0434 - accuracy: 0.9859 - val_loss: 0.0642 - val_accuracy: 0.9808
# Epoch 3/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0309 - accuracy: 0.9898 - val_loss: 0.0469 - val_accuracy: 0.9864
# Epoch 4/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0248 - accuracy: 0.9920 - val_loss: 0.0500 - val_accuracy: 0.9869
# Epoch 5/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0185 - accuracy: 0.9942 - val_loss: 0.0729 - val_accuracy: 0.9837
# Epoch 6/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0202 - accuracy: 0.9935 - val_loss: 0.0605 - val_accuracy: 0.9859
# Epoch 7/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0151 - accuracy: 0.9947 - val_loss: 0.0719 - val_accuracy: 0.9866
# Epoch 8/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0127 - accuracy: 0.9959 - val_loss: 0.0799 - val_accuracy: 0.9847
# Epoch 9/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0147 - accuracy: 0.9958 - val_loss: 0.0675 - val_accuracy: 0.9863
# Epoch 10/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0136 - accuracy: 0.9959 - val_loss: 0.0652 - val_accuracy: 0.9883
# Epoch 11/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0114 - accuracy: 0.9963 - val_loss: 0.0661 - val_accuracy: 0.9875
# Epoch 12/50
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0109 - accuracy: 0.9967 - val_loss: 0.0889 - val_accuracy: 0.9871
# Epoch 13/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0106 - accuracy: 0.9965 - val_loss: 0.0841 - val_accuracy: 0.9861
# Epoch 14/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0104 - accuracy: 0.9971 - val_loss: 0.1070 - val_accuracy: 0.9844
# Epoch 15/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0098 - accuracy: 0.9971 - val_loss: 0.0819 - val_accuracy: 0.9868
# Epoch 16/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0086 - accuracy: 0.9975 - val_loss: 0.0821 - val_accuracy: 0.9888
# Epoch 17/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0110 - accuracy: 0.9971 - val_loss: 0.0708 - val_accuracy: 0.9896
# Epoch 18/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0100 - accuracy: 0.9973 - val_loss: 0.0775 - val_accuracy: 0.9893
# Epoch 19/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0082 - accuracy: 0.9979 - val_loss: 0.0971 - val_accuracy: 0.9882
# Epoch 20/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0079 - accuracy: 0.9979 - val_loss: 0.0994 - val_accuracy: 0.9878
# Epoch 21/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0083 - accuracy: 0.9974 - val_loss: 0.1055 - val_accuracy: 0.9880
# Epoch 22/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0094 - accuracy: 0.9976 - val_loss: 0.0962 - val_accuracy: 0.9876
# Epoch 23/50
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0093 - accuracy: 0.9974 - val_loss: 0.0895 - val_accuracy: 0.9878
# Epoch 24/50
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0069 - accuracy: 0.9981 - val_loss: 0.0985 - val_accuracy: 0.9891
# Epoch 25/50
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0056 - accuracy: 0.9983 - val_loss: 0.0924 - val_accuracy: 0.9891
# Epoch 26/50
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0087 - accuracy: 0.9977 - val_loss: 0.1043 - val_accuracy: 0.9875
# Epoch 27/50
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0081 - accuracy: 0.9981 - val_loss: 0.1045 - val_accuracy: 0.9884
# Epoch 28/50
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0073 - accuracy: 0.9981 - val_loss: 0.1153 - val_accuracy: 0.9815
# Epoch 29/50
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0077 - accuracy: 0.9984 - val_loss: 0.1086 - val_accuracy: 0.9866
# Epoch 30/50
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0078 - accuracy: 0.9979 - val_loss: 0.1221 - val_accuracy: 0.9875
# Epoch 31/50
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0063 - accuracy: 0.9983 - val_loss: 0.1226 - val_accuracy: 0.9871
# Epoch 32/50
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0068 - accuracy: 0.9983 - val_loss: 0.1063 - val_accuracy: 0.9890
# Epoch 33/50
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0062 - accuracy: 0.9985 - val_loss: 0.1311 - val_accuracy: 0.9887
# Epoch 34/50
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.0075 - accuracy: 0.9984 - val_loss: 0.1371 - val_accuracy: 0.9878
# Epoch 35/50
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.0081 - accuracy: 0.9982 - val_loss: 0.1342 - val_accuracy: 0.9871
# Epoch 36/50
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0088 - accuracy: 0.9980 - val_loss: 0.1615 - val_accuracy: 0.9876
# Epoch 37/50
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.0074 - accuracy: 0.9983 - val_loss: 0.1466 - val_accuracy: 0.9862
# Epoch 38/50
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0071 - accuracy: 0.9984 - val_loss: 0.1261 - val_accuracy: 0.9893
# Epoch 39/50
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0057 - accuracy: 0.9988 - val_loss: 0.1334 - val_accuracy: 0.9864
# Epoch 40/50
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0067 - accuracy: 0.9986 - val_loss: 0.1418 - val_accuracy: 0.9891
# Epoch 41/50
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0065 - accuracy: 0.9982 - val_loss: 0.1568 - val_accuracy: 0.9855
# Epoch 42/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0083 - accuracy: 0.9983 - val_loss: 0.1417 - val_accuracy: 0.9884
# Epoch 43/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0062 - accuracy: 0.9986 - val_loss: 0.1306 - val_accuracy: 0.9866
# Epoch 44/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0060 - accuracy: 0.9985 - val_loss: 0.1481 - val_accuracy: 0.9883
# Epoch 45/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0076 - accuracy: 0.9984 - val_loss: 0.1223 - val_accuracy: 0.9893
# Epoch 46/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0070 - accuracy: 0.9984 - val_loss: 0.1357 - val_accuracy: 0.9895
# Epoch 47/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0058 - accuracy: 0.9986 - val_loss: 0.1293 - val_accuracy: 0.9901
# Epoch 48/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0073 - accuracy: 0.9984 - val_loss: 0.1408 - val_accuracy: 0.9887
# Epoch 49/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0080 - accuracy: 0.9986 - val_loss: 0.1800 - val_accuracy: 0.9854
# Epoch 50/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0077 - accuracy: 0.9984 - val_loss: 0.1670 - val_accuracy: 0.9879

# %% [markdown]
# ### Observations and Analysis:
#
# 1. **CNN Model (Normal):**
#    - The accuracy starts at approximately 95.37% and shows a rapid increase within the initial epochs, reaching around 99.97% by the 30th epoch.
#    - CNNs are highly effective for image-related tasks due to their ability to capture hierarchical features, resulting in a rapid and substantial improvement in accuracy.
#    - The trend indicates that the CNN model effectively learns complex features in the images and achieves a very high accuracy within a relatively small number of epochs.
#
# 2. **CNN Model with Dropout:**
#    - The accuracy starts at approximately 95.34% and follows a similar trend to the normal CNN model but with more fluctuations and a slightly slower rate of increase.
#    - Dropout helps reduce overfitting, but it may introduce fluctuations in accuracy as neurons are randomly dropped during training.
#    - The fluctuations in accuracy may be attributed to the stochastic nature of dropout, affecting the model's performance during training.
#
# 3. **CNN Model with BatchNormalization:**
#    - The accuracy starts at approximately 96.45% and exhibits a smooth and steady increase throughout the epochs, reaching around 99.88% by the 30th epoch.
#    - Batch normalization helps in stabilizing and accelerating the learning process, resulting in a smoother accuracy curve and faster convergence compared to the normal CNN model.
#    - The trend suggests that batch normalization allows the model to learn more efficiently and achieve a high accuracy within the same number of epochs.
#
# ### Summary:
# - The normal CNN model demonstrates a rapid and consistent increase in accuracy, converging quickly to a very high accuracy, showcasing the effectiveness of CNNs for image-related tasks.
# - The CNN model with dropout exhibits a similar increasing trend but with more fluctuations, highlighting the effect of dropout in reducing overfitting and potentially introducing more variability in the accuracy.
# - The CNN model with batch normalization showcases a smooth and steady increase in accuracy, demonstrating the benefits of batch normalization in stabilizing and accelerating the learning process in CNNs.
#
# These observations emphasize the importance of architectural choices, such as dropout and batch normalization, in enhancing the training dynamics and performance of CNNs for image classification tasks.

# %%
plt.plot(cnn_accuracy,label='Normal CNN')
plt.plot(mlp_accuracy,label='Normal MLP')
plt.plot(softmax_accuracy,label='Normal Softmax')
plt.legend()

# %% [markdown]
# ### Comparison: Normal Softmax Regression vs. Normal MLP vs. Normal CNN
#
# 1. **Normal Softmax Regression:**
#    - **Highest Achieved Accuracy:** ~93.52%
#    - **Accuracy Trend:** Steady increase, moderate accuracy.
#    - **Performance:** Achieves a moderate accuracy on the MNIST dataset. Suitable for simpler tasks due to its basic architecture without hidden layers.
#
# 2. **Normal MLP:**
#    - **Highest Achieved Accuracy:** ~99.84%
#    - **Accuracy Trend:** Rapid and consistent increase, high accuracy.
#    - **Performance:** Achieves a very high accuracy quickly, showcasing the power of multiple hidden layers to learn complex features in the data.
#
# 3. **Normal CNN:**
#    - **Highest Achieved Accuracy:** ~99.97%
#    - **Accuracy Trend:** Rapid and consistent increase, very high accuracy.
#    - **Performance:** Achieves an extremely high accuracy rapidly, emphasizing its effectiveness in image classification tasks.
#
# ### Summary:
# - Softmax Regression provides moderate accuracy and is suitable for simpler tasks.
# - MLP achieves a very high accuracy quickly, making it versatile for various tasks.
# - CNN achieves an extremely high accuracy rapidly, especially for image classification, due to its ability to capture spatial features effectively.
#
# Considering the outputs and observed trends, the CNN model achieves the highest accuracy and demonstrates rapid convergence, making it superior for image classification tasks like the MNIST dataset. MLP also achieves high accuracy, showcasing its versatility for various tasks. Softmax Regression, while simpler and achieving a moderate accuracy, may be limited in handling more complex tasks compared to MLP and CNN.
#
# In conclusion, for image-related tasks like MNIST digit classification, the CNN model stands out as the most effective and efficient choice based on the achieved accuracy and convergence speed.

# %%
plt.plot(cnn_batch_norm_accuracy,label='Batch NORM CNN')
plt.plot(mlp_batch_norm_accuracy,label='Batch NORM MLP')
plt.plot(softmax_batch_norm_accuracy,label='Batch NORM Softmax')
plt.legend()

# %% [markdown]
# ### Comparison: Softmax Regression with Dropout vs. MLP with Dropout vs. CNN with Dropout
#
# 1. **Softmax Regression with Dropout:**
#    - **Highest Achieved Accuracy:** ~93.57%
#    - **Accuracy Trend:** Fluctuating but increasing trend, moderate to high accuracy.
#    - **Performance:** Achieves a moderate to high accuracy and demonstrates improvement over regular softmax regression by reducing overfitting through dropout.
#
# 2. **MLP with Dropout:**
#    - **Highest Achieved Accuracy:** ~98.28%
#    - **Accuracy Trend:** Fluctuating but increasing trend, high accuracy.
#    - **Performance:** Achieves a high accuracy, effectively using dropout to reduce overfitting and generalize well.
#
# 3. **CNN with Dropout:**
#    - **Highest Achieved Accuracy:** ~99.15%
#    - **Accuracy Trend:** Fluctuating but increasing trend, very high accuracy.
#    - **Performance:** Achieves a very high accuracy, indicating that dropout effectively reduces overfitting and aids in faster convergence.
#
# ### Summary:
# - **Softmax Regression with Dropout:** Enhances accuracy and reduces overfitting compared to regular softmax regression, making it more suitable for the given task.
# - **MLP with Dropout:** Demonstrates a high accuracy and effectively leverages dropout to generalize the model and reduce overfitting.
# - **CNN with Dropout:** Achieves the highest accuracy among the models with dropout, indicating the effectiveness of dropout in CNNs for image classification tasks.
#
# In summary, when dropout is applied, CNN with dropout achieves the highest accuracy, making it the most effective choice for image classification tasks. MLP with dropout also achieves a high accuracy, showcasing its effectiveness. Softmax regression with dropout improves accuracy compared to the regular softmax regression, making it a viable option, especially for simpler tasks. However, for image classification, the CNN model with dropout stands out as the most effective choice based on the achieved accuracy.

# %%
plt.plot(cnn_dropout_accuracy,label='Dropout CNN')
plt.plot(mlp_batch_norm_accuracy,label='Dropout MLP')
plt.plot(softmax_dropout_accuracy,label='Dropout Softmax')
plt.legend()

# %% [markdown]
# ### Comparison: Softmax Regression with Batch Normalization vs. MLP with Batch Normalization vs. CNN with Batch Normalization
#
# 1. **Softmax Regression with Batch Normalization:**
#    - **Highest Achieved Accuracy:** ~91.83%
#    - **Accuracy Trend:** Steady increase, moderate to high accuracy.
#    - **Performance:** Achieves a moderate to high accuracy and demonstrates improvement over regular softmax regression through the use of batch normalization.
#
# 2. **MLP with Batch Normalization:**
#    - **Highest Achieved Accuracy:** ~99.48%
#    - **Accuracy Trend:** Steady increase, very high accuracy.
#    - **Performance:** Achieves a very high accuracy, indicating the effectiveness of batch normalization in stabilizing and accelerating training.
#
# 3. **CNN with Batch Normalization:**
#    - **Highest Achieved Accuracy:** ~99.88%
#    - **Accuracy Trend:** Steady increase, very high accuracy.
#    - **Performance:** Achieves an extremely high accuracy, demonstrating the significant impact of batch normalization in CNNs.
#
# ### Summary:
# - **Softmax Regression with Batch Normalization:** Enhances accuracy compared to regular softmax regression by stabilizing and accelerating the learning process, making it more suitable for the given task.
# - **MLP with Batch Normalization:** Achieves a very high accuracy and demonstrates the effectiveness of batch normalization in stabilizing the training process and improving the model's generalization.
# - **CNN with Batch Normalization:** Achieves the highest accuracy among the models with batch normalization, indicating the significant impact of batch normalization in CNNs for image classification tasks.
#
# In summary, when batch normalization is applied, CNN with batch normalization achieves the highest accuracy, making it the most effective choice for image classification tasks. MLP with batch normalization also achieves a very high accuracy, showcasing its effectiveness. Softmax regression with batch normalization improves accuracy compared to regular softmax regression, making it a viable option, especially for simpler tasks. However, for image classification, the CNN model with batch normalization stands out as the most effective choice based on the achieved accuracy.
